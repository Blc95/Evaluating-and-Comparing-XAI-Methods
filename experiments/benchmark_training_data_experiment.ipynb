# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Thesis_XAI/XAI
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Thesis_XAI/XAI

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %%
# !pip uninstall -y tensorflow tensorflow-text tf-keras jax tensorstore ml-dtypes protobuf
# !pip install "tensorflow==2.14.0" "numpy<2.0" "ml-dtypes==0.2.0" protobuf==4.25.3 --quiet --no-cache-dir
# !pip install dl-backtrace graphviz lime shap --quiet
# !pip install numpy==1.24.3 pandas==1.5.3 matplotlib==3.7.1 seaborn==0.12.2 scikit-learn==1.3.2 scipy==1.10.1
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Found existing installation: tensorflow-text 2.18.1
# Uninstalling tensorflow-text-2.18.1:
#   Successfully uninstalled tensorflow-text-2.18.1
# Found existing installation: tf_keras 2.18.0
# Uninstalling tf_keras-2.18.0:
#   Successfully uninstalled tf_keras-2.18.0
# Found existing installation: jax 0.5.2
# Uninstalling jax-0.5.2:
#   Successfully uninstalled jax-0.5.2
# Found existing installation: tensorstore 0.1.74
# Uninstalling tensorstore-0.1.74:
#   Successfully uninstalled tensorstore-0.1.74
# Found existing installation: ml-dtypes 0.4.1
# Uninstalling ml-dtypes-0.4.1:
#   Successfully uninstalled ml-dtypes-0.4.1
# Found existing installation: protobuf 5.29.5
# Uninstalling protobuf-5.29.5:
#   Successfully uninstalled protobuf-5.29.5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.9/489.9 MB 172.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 356.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 345.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 253.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 339.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 277.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 332.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 232.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.89 requires jax>=0.4.27, which is not installed.
# dopamine-rl 4.1.2 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, which is not installed.
# flax 0.10.6 requires jax>=0.5.1, which is not installed.
# flax 0.10.6 requires tensorstore, which is not installed.
# keras-hub 0.18.1 requires tensorflow-text; platform_system != "Darwin", which is not installed.
# optax 0.2.5 requires jax>=0.4.27, which is not installed.
# orbax-checkpoint 0.11.16 requires jax>=0.5.0, which is not installed.
# orbax-checkpoint 0.11.16 requires tensorstore>=0.1.71, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tf-keras~=2.17, which is not installed.
# tensorflow-hub 0.16.1 requires tf-keras>=2.14.1, which is not installed.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 111.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 138.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 118.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 52.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 109.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 92.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 83.2 MB/s eta 0:00:00
#   Building wheel for lime (setup.py) ... done
# Collecting numpy==1.24.3
#   Downloading numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting pandas==1.5.3
#   Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting matplotlib==3.7.1
#   Downloading matplotlib-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting seaborn==0.12.2
#   Downloading seaborn-0.12.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn==1.3.2
#   Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.10.1
#   Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1) (3.2.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.17.0)
# Downloading numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 32.7 MB/s eta 0:00:00
# Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 66.4 MB/s eta 0:00:00
# Downloading matplotlib-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 77.6 MB/s eta 0:00:00
# Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 33.2 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 77.3 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 37.5 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, pandas, scikit-learn, matplotlib, seaborn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.89 requires jax>=0.4.27, which is not installed.
# dopamine-rl 4.1.2 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, which is not installed.
# flax 0.10.6 requires jax>=0.5.1, which is not installed.
# flax 0.10.6 requires tensorstore, which is not installed.
# keras-hub 0.18.1 requires tensorflow-text; platform_system != "Darwin", which is not installed.
# optax 0.2.5 requires jax>=0.4.27, which is not installed.
# orbax-checkpoint 0.11.16 requires jax>=0.5.0, which is not installed.
# orbax-checkpoint 0.11.16 requires tensorstore>=0.1.71, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tf-keras~=2.17, which is not installed.
# tensorflow-hub 0.16.1 requires tf-keras>=2.14.1, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# blosc2 3.5.1 requires numpy>=1.26, but you have numpy 1.24.3 which is incompatible.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# cvxpy 1.6.6 requires scipy>=1.11.0, but you have scipy 1.10.1 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# dask-expr 1.1.21 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# jaxlib 0.5.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.3 which is incompatible.
# plotnine 0.14.6 requires matplotlib>=3.8.0, but you have matplotlib 3.7.1 which is incompatible.
# plotnine 0.14.6 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# pymc 5.23.0 requires numpy>=1.25.0, but you have numpy 1.24.3 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.3 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.3 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.3.2 which is incompatible.
# xarray 2025.3.1 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# xarray-einstats 0.9.1 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# xarray-einstats 0.9.1 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed matplotlib-3.7.1 numpy-1.24.3 pandas-1.5.3 scikit-learn-1.3.2 scipy-1.10.1 seaborn-0.12.2

# %%
# !pip install xai_evals
# Out:
# Collecting xai_evals
#   Downloading xai_evals-0.0.12-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: dl_backtrace in /usr/local/lib/python3.11/dist-packages (from xai_evals) (0.1.5)
# Collecting shap==0.46.0 (from xai_evals)
#   Downloading shap-0.46.0-cp311-cp311-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: lime==0.2.0.1 in /usr/local/lib/python3.11/dist-packages (from xai_evals) (0.2.0.1)
# Collecting xgboost==2.1.3 (from xai_evals)
#   Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.11/dist-packages (from xai_evals) (1.3.2)
# Collecting pandas==2.1.4 (from xai_evals)
#   Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting numpy==1.26.4 (from xai_evals)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.9 MB/s eta 0:00:00
# Collecting catboost==1.2.7 (from xai_evals)
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: lightgbm==4.5.0 in /usr/local/lib/python3.11/dist-packages (from xai_evals) (4.5.0)
# Requirement already satisfied: tensorflow==2.14.0 in /usr/local/lib/python3.11/dist-packages (from xai_evals) (2.14.0)
# Collecting captum==0.7.0 (from xai_evals)
#   Downloading captum-0.7.0-py3-none-any.whl.metadata (26 kB)
# Collecting quantus==0.5.3 (from xai_evals)
#   Downloading quantus-0.5.3-py3-none-any.whl.metadata (34 kB)
# Collecting tf-explain (from xai_evals)
#   Downloading tf_explain-0.3.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from xai_evals) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from xai_evals) (4.67.1)
# Requirement already satisfied: opencv-python==4.11.0.86 in /usr/local/lib/python3.11/dist-packages (from xai_evals) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum==0.7.0->xai_evals) (3.7.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->xai_evals) (0.21)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->xai_evals) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->xai_evals) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->xai_evals) (1.17.0)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime==0.2.0.1->xai_evals) (0.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas==2.1.4->xai_evals) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.1.4->xai_evals) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.1.4->xai_evals) (2025.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->xai_evals) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->xai_evals) (3.6.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap==0.46.0->xai_evals) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap==0.46.0->xai_evals) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from shap==0.46.0->xai_evals) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap==0.46.0->xai_evals) (3.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (4.25.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (4.14.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (1.73.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.14.0->xai_evals) (2.14.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost==2.1.3->xai_evals) (2.21.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (0.6.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->xai_evals) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->xai_evals) (1.3.0)
# Requirement already satisfied: transformers==4.52.3 in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (4.52.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (0.33.4)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (4.4.5)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (0.12.2)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (1.13.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (7.7.1)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.11/dist-packages (from dl_backtrace->xai_evals) (0.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.52.3->dl_backtrace->xai_evals) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.52.3->dl_backtrace->xai_evals) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.52.3->dl_backtrace->xai_evals) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.52.3->dl_backtrace->xai_evals) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.52.3->dl_backtrace->xai_evals) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.14.0->xai_evals) (0.45.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->dl_backtrace->xai_evals) (1.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum==0.7.0->xai_evals) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum==0.7.0->xai_evals) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum==0.7.0->xai_evals) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum==0.7.0->xai_evals) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum==0.7.0->xai_evals) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum==0.7.0->xai_evals) (3.2.3)
# Collecting scipy (from catboost==1.2.7->xai_evals)
#   Downloading scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime==0.2.0.1->xai_evals) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime==0.2.0.1->xai_evals) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime==0.2.0.1->xai_evals) (0.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (3.1.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->dl_backtrace->xai_evals) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->dl_backtrace->xai_evals) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->dl_backtrace->xai_evals) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->dl_backtrace->xai_evals) (3.0.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->xai_evals) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->shap==0.46.0->xai_evals) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost==1.2.7->xai_evals) (8.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (2.0.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (4.9.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel->dl_backtrace->xai_evals) (5.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.52.3->dl_backtrace->xai_evals) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.52.3->dl_backtrace->xai_evals) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.52.3->dl_backtrace->xai_evals) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.52.3->dl_backtrace->xai_evals) (2025.7.14)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel->dl_backtrace->xai_evals) (4.3.8)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->dl_backtrace->xai_evals) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0->xai_evals) (3.3.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (4.24.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (0.26.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->dl_backtrace->xai_evals) (1.3.1)
# Downloading xai_evals-0.0.12-py3-none-any.whl (31 kB)
# Downloading captum-0.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.7 MB/s eta 0:00:00
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 27.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 95.6 MB/s eta 0:00:00
# Downloading pandas-2.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 111.4 MB/s eta 0:00:00
# Downloading quantus-0.5.3-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 26.3 MB/s eta 0:00:00
# Downloading shap-0.46.0-cp311-cp311-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.2/540.2 kB 49.7 MB/s eta 0:00:00
# Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 13.3 MB/s eta 0:00:00
# Downloading tf_explain-0.3.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.3 MB/s eta 0:00:00
# Downloading scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 68.7 MB/s eta 0:00:00
# Installing collected packages: tf-explain, numpy, scipy, pandas, xgboost, shap, quantus, catboost, captum, xai_evals
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.4
#     Uninstalling xgboost-2.1.4:
#       Successfully uninstalled xgboost-2.1.4
#   Attempting uninstall: shap
#     Found existing installation: shap 0.48.0
#     Uninstalling shap-0.48.0:
#       Successfully uninstalled shap-0.48.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.89 requires jax>=0.4.27, which is not installed.
# dopamine-rl 4.1.2 requires jax>=0.1.72, which is not installed.
# dopamine-rl 4.1.2 requires tf-keras>=2.18.0, which is not installed.
# flax 0.10.6 requires jax>=0.5.1, which is not installed.
# flax 0.10.6 requires tensorstore, which is not installed.
# keras-hub 0.18.1 requires tensorflow-text; platform_system != "Darwin", which is not installed.
# optax 0.2.5 requires jax>=0.4.27, which is not installed.
# orbax-checkpoint 0.11.16 requires jax>=0.5.0, which is not installed.
# orbax-checkpoint 0.11.16 requires tensorstore>=0.1.71, which is not installed.
# tensorflow-decision-forests 1.11.0 requires tf-keras~=2.17, which is not installed.
# tensorflow-hub 0.16.1 requires tf-keras>=2.14.1, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.6 requires matplotlib>=3.8.0, but you have matplotlib 3.7.1 which is incompatible.
# plotnine 0.14.6 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# plotnine 0.14.6 requires scipy<1.16.0,>=1.8.0, but you have scipy 1.16.3 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.14.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.3.2 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed captum-0.7.0 catboost-1.2.7 numpy-1.26.4 pandas-2.1.4 quantus-0.5.3 scipy-1.16.3 shap-0.46.0 tf-explain-0.3.1 xai_evals-0.0.12 xgboost-2.1.3

# %%
# !pip install dl-backtrace==0.0.19 --quiet --no-cache-dir
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 6.8 MB/s eta 0:00:00

# %%
from xai_evals.metrics import ExplanationMetricsTabular

# %%
import numpy as np
import pandas as pd
import shap
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
from sklearn.feature_selection import f_classif
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import json
import sys, os, importlib
from sklearn.metrics import accuracy_score
from scipy.stats import multivariate_normal
from matplotlib.colors import ListedColormap
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score, log_loss
from sklearn.neural_network import MLPClassifier
import pickle
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.base import clone
from sklearn.metrics import average_precision_score, roc_auc_score

# %% [markdown]
# # Importing Datasets

# %% [markdown]
# ## Breast Cancer Wisconsin

# %%
import kagglehub

# Download dataset
path = kagglehub.dataset_download("uciml/breast-cancer-wisconsin-data")

print("Path to dataset files:", path)

for file in os.listdir(path):
    print(file)

df_wisconsin = pd.read_csv(os.path.join(path, "data.csv"))

# Changing outcome variabel to 1/0 for malignant/benign
df_wisconsin["diagnosis"] = df_wisconsin["diagnosis"].map({"M": 1, "B": 0})

df_wisconsin = df_wisconsin.drop(columns=["id", "Unnamed: 32"])

print(df_wisconsin.isnull().values.any())
df_wisconsin.shape
# Out:
# Path to dataset files: /kaggle/input/breast-cancer-wisconsin-data
# data.csv
# False
# (569, 31)

# %% [markdown]
# ## Pima Indians Diabetes

# %%
path = kagglehub.dataset_download("uciml/pima-indians-diabetes-database")

for file in os.listdir(path):
    print(file)

df_pima = pd.read_csv(os.path.join(path, "diabetes.csv"))

# Replace biologically impossible zeros with NaN
invalid_zero_cols = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
df_pima[invalid_zero_cols] = df_pima[invalid_zero_cols].replace(0, np.nan)

# Replace NaNs with column medians
df_pima = df_pima.fillna(df_pima.median(numeric_only=True))

print(df_pima.isnull().values.any())
df_pima.shape
# Out:
# diabetes.csv
# False
# (768, 9)

# %% [markdown]
# ## Banknote Authentication

# %%
path = kagglehub.dataset_download("ritesaluja/bank-note-authentication-uci-data")

for file in os.listdir(path):
    print(file)

df_bankn = pd.read_csv(os.path.join(path, "BankNote_Authentication.csv"))

print(df_bankn.isnull().values.any())
df_bankn.shape
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.12), please consider upgrading to the latest version (0.3.13).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ritesaluja/bank-note-authentication-uci-data?dataset_version_number=1...
# 100%|██████████| 19.2k/19.2k [00:00<00:00, 26.3MB/s]
# Extracting files...
# BankNote_Authentication.csv
# False
# (1372, 5)

# %% [markdown]
# # Splitting data in Train and Test sets

# %%
### BREASTCANCER IN WISCONSIN ###
# Dropping "Unnamed" column and target column
X_wisconsin = df_wisconsin.drop(columns=["diagnosis"])
# Extracting target column
y_wisconsin = df_wisconsin["diagnosis"]




### PIMA INDIANS DIABETES ###
# Dropping target
X_pima = df_pima.drop(columns=["Outcome"])
# extracting target
y_pima = df_pima["Outcome"]




### BANKNOTE AUTHENTICATION ###
X_bankn = df_bankn.drop(columns=["class"])
y_bankn = df_bankn["class"]

# %% [markdown]
# # Fix one test split

# %%
RANDOM_STATE = 42

# Wisconsin
X_wis_initial_train, X_wis_test, y_wis_initial_train, y_wis_test = train_test_split(
    X_wisconsin, y_wisconsin, test_size=0.20, stratify=y_wisconsin, random_state=RANDOM_STATE
)

# Pima
X_pima_initial_train, X_pima_test, y_pima_initial_train, y_pima_test = train_test_split(
    X_pima, y_pima, test_size=0.20, stratify=y_pima, random_state=RANDOM_STATE
)

# Banknote
X_bankn_initial_train, X_bankn_test, y_bankn_initial_train, y_bankn_test = train_test_split(
    X_bankn, y_bankn, test_size=0.20, stratify=y_bankn, random_state=RANDOM_STATE
)

# %% [markdown]
# # Information of datasets

# %%
X_wis_test.shape
# Out:
# (114, 30)

# %%
y_wis_test.value_counts()
# Out:
# diagnosis
# 0    72
# 1    42
# Name: count, dtype: int64

# %%
X_pima_test.shape
# Out:
# (154, 8)

# %%
y_pima_test.value_counts()
# Out:
# Outcome
# 0    100
# 1     54
# Name: count, dtype: int64

# %%
X_bankn_test.shape
# Out:
# (275, 4)

# %%
y_bankn_test.value_counts()
# Out:
# class
# 0    153
# 1    122
# Name: count, dtype: int64

# %%
X_cc_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-26-2157682728.py in <cell line: 0>()
# ----> 1 X_cc_test.shape
#
# NameError: name 'X_cc_test' is not defined

# %%
y_cc_test.value_counts()

# %% [markdown]
# # Computing Correlation

# %%
def avg_abs_correlation(X: pd.DataFrame) -> float:
    """
    Compute average absolute pairwise correlation between features.
    """
    corr = X.corr()
    abs_corr = corr.abs()

    # Remove diagonal
    upper = abs_corr.where(np.triu(np.ones(abs_corr.shape), k=1).astype(bool))

    return upper.stack().mean()

# %%
avg_corr_wis = avg_abs_correlation(X_wis_initial_train)
avg_corr_pima = avg_abs_correlation(X_pima_initial_train)
avg_corr_bankn = avg_abs_correlation(X_bankn_initial_train)

print(f"Wisconsin avg abs corr: {avg_corr_wis:.3f}")
print(f"Pima avg abs corr:      {avg_corr_pima:.3f}")
print(f"Banknote avg abs corr:  {avg_corr_bankn:.3f}")
# Out:
# Wisconsin avg abs corr: 0.397
# Pima avg abs corr:      0.187
# Banknote avg abs corr:  0.424

# %%
def class_balance(y):
    return float(y.mean())

print("Wisconsin train pos rate:", class_balance(y_wis_initial_train))
print("Pima train pos rate:", class_balance(y_pima_initial_train))
print("Banknote train pos rate:", class_balance(y_bankn_initial_train))
# Out:
# Wisconsin train pos rate: 0.37362637362637363
# Pima train pos rate: 0.3485342019543974
# Banknote train pos rate: 0.4448495897903373

# %%
y_wis_initial_train.value_counts()
# Out:
# diagnosis
# 0    285
# 1    170
# Name: count, dtype: int64

# %%
y_pima_initial_train.value_counts()
# Out:
# Outcome
# 0    400
# 1    214
# Name: count, dtype: int64

# %%
y_bankn_initial_train.value_counts()
# Out:
# class
# 0    609
# 1    488
# Name: count, dtype: int64

# %%
def corr_vals(X: pd.DataFrame) -> pd.Series:
    corr = X.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    return upper.stack().sort_values(ascending=False)

vals_bank = corr_vals(X_bankn_initial_train)
vals_wis  = corr_vals(X_wis_initial_train)
vals_pima = corr_vals(X_pima_initial_train)

print("Banknote top correlations:\n", vals_bank.head(10), "\n")
print("Banknote summary:", vals_bank.describe()[["count","mean","50%","max"]])
# Out:
# Banknote top correlations:
#  skewness  curtosis    0.785972
#           entropy     0.525579
# variance  curtosis    0.381403
# curtosis  entropy     0.302126
# variance  entropy     0.289101
#           skewness    0.261033
# dtype: float64
#
# Banknote summary: count    6.000000
# mean     0.424202
# 50%      0.341765
# max      0.785972
# dtype: float64

# %% [markdown]
# # Define base model that will be trained on different amount of training data

# %%
MODEL_RANDOM_STATE = 20

# Define baseline models, scaling the data where needed

# Base Logistic Regression model
base_lm = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(
        max_iter=2000,
        random_state=MODEL_RANDOM_STATE))
])

# Base Random Forest model
base_rf = Pipeline([
    ("model", RandomForestClassifier(
        n_estimators=500,
        random_state=MODEL_RANDOM_STATE))
])

# Base Gradient Boosting model
base_gb = Pipeline([
    ("model", GradientBoostingClassifier(
        n_estimators=500,
        random_state=MODEL_RANDOM_STATE))
])

# Base MLP model
base_nn = Pipeline([
    ("scaler", StandardScaler()),
    ("model", MLPClassifier(
        hidden_layer_sizes=(16,),
        solver="adam",
        alpha=1e-4, learning_rate_init=1e-3,
        max_iter=2000, early_stopping=True,
        n_iter_no_change=20,
        random_state=MODEL_RANDOM_STATE
    ))
])

# %%
SEED = 1

tiers = {
    "low": 0.10,
    "med": 0.50,
    "high": 1.00
}

def make_subset(X_full, y_full, frac, seed):
    """Return a stratified subset of size 'frac'"""
    if frac >= 0.999:
        return X_full, y_full
    X_sub, _, y_sub, _ = train_test_split(
        X_full, y_full, train_size=frac, stratify=y_full, random_state=seed
    )
    return X_sub, y_sub

# %% [markdown]
# # Information on different train sets

# %% [markdown]
# ## Wisconsin

# %%
X_wis_100, y_wis_100 = make_subset(X_wis_initial_train, y_wis_initial_train, 1.00, SEED)
X_wis_50, y_wis_50 = make_subset(X_wis_initial_train, y_wis_initial_train, 0.5, SEED)
X_wis_10, y_wis_10 = make_subset(X_wis_initial_train, y_wis_initial_train, 0.1, SEED)

print(X_wis_100.shape)
print(y_wis_100.value_counts())
print(f"\n")
print(X_wis_50.shape)
print(y_wis_50.value_counts())
print(f"\n")
print(X_wis_10.shape)
print(y_wis_10.value_counts())
# Out:
# (455, 30)
# diagnosis
# 0    285
# 1    170
# Name: count, dtype: int64
#
#
# (227, 30)
# diagnosis
# 0    142
# 1     85
# Name: count, dtype: int64
#
#
# (45, 30)
# diagnosis
# 0    28
# 1    17
# Name: count, dtype: int64

# %% [markdown]
# ## Pima

# %%
X_pima_100, y_pima_100 = make_subset(X_pima_initial_train, y_pima_initial_train, 1.00, SEED)
X_pima_50, y_pima_50 = make_subset(X_pima_initial_train, y_pima_initial_train, 0.5, SEED)
X_pima_10, y_pima_10 = make_subset(X_pima_initial_train, y_pima_initial_train, 0.1, SEED)

print(X_pima_100.shape)
print(y_pima_100.value_counts())
print(f"\n")
print(X_pima_50.shape)
print(y_pima_50.value_counts())
print(f"\n")
print(X_pima_10.shape)
print(y_pima_10.value_counts())
# Out:
# (614, 8)
# Outcome
# 0    400
# 1    214
# Name: count, dtype: int64
#
#
# (307, 8)
# Outcome
# 0    200
# 1    107
# Name: count, dtype: int64
#
#
# (61, 8)
# Outcome
# 0    40
# 1    21
# Name: count, dtype: int64

# %%
X_bankn_100, y_bankn_100 = make_subset(X_bankn_initial_train, y_bankn_initial_train, 1.00, SEED)
X_bankn_50, y_bankn_50 = make_subset(X_bankn_initial_train, y_bankn_initial_train, 0.5, SEED)
X_bankn_10, y_bankn_10 = make_subset(X_bankn_initial_train, y_bankn_initial_train, 0.1, SEED)

print(X_bankn_100.shape)
print(y_bankn_100.value_counts())
print(f"\n")
print(X_bankn_50.shape)
print(y_bankn_50.value_counts())
print(f"\n")
print(X_bankn_10.shape)
print(y_bankn_10.value_counts())
# Out:
# (1097, 4)
# class
# 0    609
# 1    488
# Name: count, dtype: int64
#
#
# (548, 4)
# class
# 0    304
# 1    244
# Name: count, dtype: int64
#
#
# (109, 4)
# class
# 0    61
# 1    48
# Name: count, dtype: int64

# %%
X_cc_100, y_cc_100 = make_subset(X_cc_initial_train, y_cc_initial_train, 1.00, SEED)
X_cc_50, y_cc_50 = make_subset(X_cc_initial_train, y_cc_initial_train, 0.5, SEED)
X_cc_10, y_cc_10 = make_subset(X_cc_initial_train, y_cc_initial_train, 0.1, SEED)

print(X_cc_100.shape)
print(y_cc_100.value_counts())
print(f"\n")
print(X_cc_50.shape)
print(y_cc_50.value_counts())
print(f"\n")
print(X_cc_10.shape)
print(y_cc_10.value_counts())
# Out:
# (227845, 30)
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64
#
#
# (113922, 30)
# Class
# 0    113725
# 1       197
# Name: count, dtype: int64
#
#
# (22784, 30)
# Class
# 0    22745
# 1       39
# Name: count, dtype: int64

# %% [markdown]
# # Training the Models

# %%
rows = []
models_store = {}

models_performance = {}

# Change train set here
X_train_initial = X_bankn_initial_train
y_train_initial = y_bankn_initial_train

# change test set here
X_test = X_bankn_test
y_test = y_bankn_test

# Change name of dataset here
dataset = "banknote"


# Change model here
model = base_nn
# change name of model here
model_name = "nn"


for tier_name, frac in tiers.items():
        # Sample the training subset for this tier/seed
        X_train_sub, y_train_sub = make_subset(X_train_initial, y_train_initial, frac, SEED)

        # Train the same model on this subset
        model = clone(model) ### CHANGE MODEL HERE ###
        model.fit(X_train_sub, y_train_sub)

        # Evaluate on the test set
        preds = model.predict(X_test)
        acc = accuracy_score(y_test, preds)
        f1_pos = f1_score(y_test, preds, average="binary", pos_label=1)

        # Probabilities of predictions
        proba = model.predict_proba(X_test)
        y_score = proba[:, 1]

        # Average precision
        ap = average_precision_score(y_test, y_score)

        # ROC
        roc = roc_auc_score(y_test, y_score)

        # Confidence in model choice
        confidences = np.max(proba, axis=1)

        # Confidecen for right/wrong predictions
        y_true = np.asarray(y_test)
        correct = (preds == y_true)
        mean_confidence_correct = np.mean(confidences[correct])
        mean_confidence_wrong   = np.mean(confidences[~correct])

        # Mean confidence across predictions
        mean_confidence = np.mean(confidences)


        rows.append({
            "model": model_name,
            "dataset": dataset,
            "tier": tier_name,
            "n_train": len(X_train_sub),
            "accuracy": acc,
            "f1_pos": f1_pos,
            "ap": ap,
            "roc_auc": roc,
            "mean_confidence": mean_confidence,
            "mean_confidence_correct": mean_confidence_correct,
            "mean_confidence_wrong": mean_confidence_wrong
        })
        models_store[(dataset, model_name, tier_name)] = model

        models_performance[(dataset, model_name, tier_name)] = ({
            "n_train": len(X_train_sub),
            "accuracy": acc,
            "f1_pos": f1_pos,
            "ap": ap,
            "roc_auc": roc,
            "mean_confidence": mean_confidence,
            "mean_confidence_correct": mean_confidence_correct,
            "mean_confidence_wrong": mean_confidence_wrong
          })

results = pd.DataFrame(rows).sort_values(["tier"])
#print(results)
#print(results.groupby("tier")[["accuracy","f1_pos","ap","roc_auc", "mean_confidence", "mean_confidence_correct", "mean_confidence_wrong"]].agg(["mean","std","min","max"]))

# %% [markdown]
# # Print results and save results

# %%
results = results.groupby("tier")[["accuracy","f1_pos","ap","roc_auc", "mean_confidence", "mean_confidence_correct", "mean_confidence_wrong"]].agg(["mean","std","min","max"])
results
# Out:
#       accuracy                            f1_pos                          \
#           mean std       min       max      mean std       min       max
# tier
# high  0.927273 NaN  0.927273  0.927273  0.921875 NaN  0.921875  0.921875
# low   0.425455 NaN  0.425455  0.425455  0.318966 NaN  0.318966  0.318966
# med   0.916364 NaN  0.916364  0.916364  0.905350 NaN  0.905350  0.905350
#
#             ap      ... mean_confidence           mean_confidence_correct      \
#           mean std  ...             min       max                    mean std
# tier                ...
# high  0.989844 NaN  ...        0.769014  0.769014                0.785673 NaN
# low   0.365592 NaN  ...        0.600968  0.600968                0.610340 NaN
# med   0.967322 NaN  ...        0.648453  0.648453                0.659252 NaN
#
#                          mean_confidence_wrong
#            min       max                  mean std       min       max
# tier
# high  0.785673  0.785673              0.556616 NaN  0.556616  0.556616
# low   0.610340  0.610340              0.594028 NaN  0.594028  0.594028
# med   0.659252  0.659252              0.530130 NaN  0.530130  0.530130
#
# [3 rows x 28 columns]

# %%
print(models_performance)
# Out:
# {('banknote', 'nn', 'low'): {'n_train': 109, 'accuracy': 0.4254545454545455, 'f1_pos': 0.3189655172413793, 'ap': 0.3655921883835137, 'roc_auc': 0.41138969248901747, 'mean_confidence': 0.600968297753393, 'mean_confidence_correct': 0.6103402779693551, 'mean_confidence_wrong': 0.5940282870871425}, ('banknote', 'nn', 'med'): {'n_train': 548, 'accuracy': 0.9163636363636364, 'f1_pos': 0.9053497942386831, 'ap': 0.9673222056293824, 'roc_auc': 0.977124183006536, 'mean_confidence': 0.6484528126417037, 'mean_confidence_correct': 0.6592521399684439, 'mean_confidence_wrong': 0.5301297480182886}, ('banknote', 'nn', 'high'): {'n_train': 1097, 'accuracy': 0.9272727272727272, 'f1_pos': 0.9218749999999999, 'ap': 0.9898443901331287, 'roc_auc': 0.9914282652951891, 'mean_confidence': 0.7690139836228463, 'mean_confidence_correct': 0.7856726123538003, 'mean_confidence_wrong': 0.5566164673031861}}

# %%
from google.colab import files

filename = "nn_model_banknote.pkl"
with open(filename, "wb") as f:
    pickle.dump(models_performance, f)

files.download(filename)

# %% [markdown]
# # Sanity Checks

# %%
for key, value in models_store.items():
  print(value)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                max_iter=2000, n_iter_no_change=20,
#                                random_state=20))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                max_iter=2000, n_iter_no_change=20,
#                                random_state=20))])
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                max_iter=2000, n_iter_no_change=20,
#                                random_state=20))])

# %%
X_test.columns
# Out:
# Index(['variance', 'skewness', 'curtosis', 'entropy'], dtype='object')

# %%
tiers.items()

for name, value in tiers.items():
  print(name)
# Out:
# low
# med
# high

# %%
models_store
# Out:
# {('banknote',
#   'nn',
#   'low'): Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model',
#                   MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                 max_iter=2000, n_iter_no_change=20,
#                                 random_state=20))]),
#  ('banknote',
#   'nn',
#   'med'): Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model',
#                   MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                 max_iter=2000, n_iter_no_change=20,
#                                 random_state=20))]),
#  ('banknote',
#   'nn',
#   'high'): Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model',
#                   MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                 max_iter=2000, n_iter_no_change=20,
#                                 random_state=20))])}

# %%
key = (dataset, model_name, tier_name)

models_store[key]


print(model)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  MLPClassifier(early_stopping=True, hidden_layer_sizes=(16,),
#                                max_iter=2000, n_iter_no_change=20,
#                                random_state=20))])

# %% [markdown]
# # Computing metrics

# %%
feature_names = list(X_test.columns)

# %%
import warnings, contextlib, os, pickle

metrics = {}
filenames = []

INSTANCES_PER_CLASS = 40
global_seed = np.random.default_rng(123)


def stratified_indices(y, per_class=10, s=None):
    '''Function for finding X instances per class'''
    y = y.ravel()
    idxs = [] # Empty list for storing indexes of instances from each class
    for c in np.unique(y): # Loop over each unique class
        cls_idx = np.where(y == c)[0] # Get indicies all all instances belonging to c
        chosen = s.choice(cls_idx, size=per_class, replace=False) # Randomly choose per_class indicies from the class index
        idxs.append(chosen) # append the chosen classes to the list of instances chosen
    idxs = np.concatenate(idxs) # concatenate the list of array into one list
    s.shuffle(idxs) # Shuffle instances
    return idxs

### CHANGE STUFF HERE ###

# Change train set here
X_train_initial = X_bankn_initial_train
y_train_initial = y_bankn_initial_train

# Change test set here
X_test = X_bankn_test
y_test = y_bankn_test

# Change name of dataset here
dataset = "banknote"

# Change method here
method = "lime"

# Change model here
model_name = "nn"
######################

test_idx = stratified_indices(y_test, per_class=INSTANCES_PER_CLASS, s=global_seed)

X_test = X_test.iloc[test_idx].values
y_test = y_test.iloc[test_idx].values



# Define traning fractions
tiers = {"low": 0.10, "med": 0.50, "high": 1.00}

# Loop through tiers and seeds
for tier_name, frac in tiers.items():

        key = (dataset, model_name, tier_name)
        print("Running metrics for:", tier_name)

        # Get the trained model
        model = models_store[key]

        # Recreate the training subset used for this model (same frac + seed)
        # This is only to derive a background set for explainers.
        X_train_sub, y_train_sub = make_subset(X_train_initial, y_train_initial, frac, SEED)

        # Background
        X_tr_bg = X_train_sub.values

        # Build the metric runner
        em = ExplanationMetricsTabular(
            model=model,
            explainer_name=method,
            X_train=shap.sample(X_tr_bg, 200),  # background from TRAIN SUBSET ONLY
            X_test=X_test,
            y_test=y_test,
            features=feature_names,
            task="binary-classification"
        )

        # Compute metrics and quiet spammy warnings
        with warnings.catch_warnings():
            with open(os.devnull, "w") as devnull, \
                 contextlib.redirect_stdout(devnull), \
                 contextlib.redirect_stderr(devnull):
                result = em.calculate_metrics()

        metrics[key] = result
        del em

        filename = f"{dataset}_{model_name}_metrics_{tier_name}_{method}_{frac}.pkl"
        with open(filename, "wb") as f:
            pickle.dump({key: result}, f)
        filenames.append(filename)
# Out:
# Running metrics for: low
# Running metrics for: med
# Running metrics for: high

# %% [markdown]
# # Save metric results

# %%
import zipfile
from google.colab import files

zip_name = f"{dataset}_{model_name}_metrics_{method}.zip"

with zipfile.ZipFile(zip_name, "w") as z:
    for fname in filenames:
        z.write(fname)

files.download(zip_name)

# %%
metrics
# Out:
# {('banknote',
#   'nn',
#   'low'):    faithfulness  infidelity  sensitivity  comprehensiveness  sufficiency  \
#  0      0.060476    0.000001     0.006686           0.019882          0.0
#
#     monotonicity  complexity  sparseness
#  0           1.0         4.0         0.0  ,
#  ('banknote',
#   'nn',
#   'med'):    faithfulness  infidelity  sensitivity  comprehensiveness  sufficiency  \
#  0      0.825802    0.000003     0.011858           0.120273          0.0
#
#     monotonicity  complexity  sparseness
#  0           1.0         4.0         0.0  ,
#  ('banknote',
#   'nn',
#   'high'):    faithfulness  infidelity  sensitivity  comprehensiveness  sufficiency  \
#  0      0.658769    0.000014     0.015391            0.08981          0.0
#
#     monotonicity  complexity  sparseness
#  0           1.0         4.0         0.0  }

# %% [markdown]
# # ONLY FOR SHAP FOR NN (de-looped version of the above, since it crashed colab (and kernel on my local machine)

# %%
import warnings, contextlib, os, pickle

metrics = {}
filenames = []

INSTANCES_PER_CLASS = 40
global_seed = np.random.default_rng(123)


def stratified_indices(y, per_class=10, s=None):
    '''Function for finding X instances per class'''
    y = y.ravel()
    idxs = []  # Empty list for storing indexes of instances from each class
    for c in np.unique(y):  # Loop over each unique class
        cls_idx = np.where(y == c)[0]  # Get indicies of all instances belonging to c
        chosen = s.choice(cls_idx, size=per_class, replace=False)  # Randomly choose per_class indicies
        idxs.append(chosen)
    idxs = np.concatenate(idxs)  # concatenate into one list
    s.shuffle(idxs)
    return idxs


### CHANGE STUFF HERE ###

# Change train set here
X_train_initial = X_bankn_initial_train
y_train_initial = y_bankn_initial_train

# change test set here
X_test = X_bankn_test
y_test = y_bankn_test

# Change name of dataset here
dataset = "banknote"

# Change method here
method = "shap"

# Change model here
model_name = "nn"

# Change tier/frac here
tier_name = "low"
frac = 0.1
##########

test_idx = stratified_indices(y_test, per_class=INSTANCES_PER_CLASS, s=global_seed)
X_test = X_test.iloc[test_idx].values
y_test = y_test.iloc[test_idx].values

key = (dataset, model_name, tier_name)
print("Running metrics for:", tier_name)

model = models_store[key]
X_train_sub, y_train_sub = make_subset(X_train_initial, y_train_initial, frac, SEED)
X_tr_bg = X_train_sub.values

em = ExplanationMetricsTabular(
    model=model,
    explainer_name=method,
    X_train=shap.sample(X_tr_bg, 200),
    X_test=X_test,
    y_test=y_test,
    features=feature_names,
    task="binary-classification"
)

with warnings.catch_warnings():
    with open(os.devnull, "w") as devnull, \
         contextlib.redirect_stdout(devnull), \
         contextlib.redirect_stderr(devnull):
        result = em.calculate_metrics()

metrics[key] = result
del em

filename = f"{dataset}_{model_name}_metrics_{tier_name}_{method}_{frac}.pkl"
with open(filename, "wb") as f:
    pickle.dump({key: result}, f)
filenames.append(filename)
# Out:
# WARNING:shap:Using 109 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running metrics for: low
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
filename = f"{dataset}_{model_name}_metrics_{tier_name}_{method}_{frac}.pkl"
with open(filename, "wb") as f:
    pickle.dump({key: result}, f)
filenames.append(filename)

# %%
print(filename)
# Out:
# banknote_nn_metrics_low_shap_0.1.pkl

# %%
from google.colab import files
files.download(filename)
